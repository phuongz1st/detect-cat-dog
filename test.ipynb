# %%
pip install pyspark
# Out:
# ...
#      ---------------------------------------- 0.0/455.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/455.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/455.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/455.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/455.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/455.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/455.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/455.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/455.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/455.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/455.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/455.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/455.4 MB ? eta -:--:--
# ...

# %%
from pyspark.sql import SparkSession
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pyspark.sql import SparkSession
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
spark = SparkSession.builder.appName("SaprkOne").\
config("spark.executor.memory","2g").\
config("spark.sql.shuffle.partitions","4").getOrCreate()

# %%
#Test hiệu năng đọc file
filepath = ""
#test1 đo hiệu năng với pandas
start_time_spark = time.time()
try :
    pandas_df = spark.read.csv(filepath, header = True, inferSchema=True)
    spark_process_time = time.time() - start_time_spark
except Exception as e:
    spark_process_time = None
    spark_error = str(e)

# %%
#Kết quả
results = {
    'Pandas read time (s)': pandas
}
